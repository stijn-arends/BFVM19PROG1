# %% [markdown]
# # Wrangling with datetime

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas has datetime objects with many handy attributes

# %%
t = pd.Timestamp.now() 
print(t.year)
print(t.month) 
print(t.day)
print(t.hour)
print(t.minute)
print(t.second)
# Out:
# 2020
# 10
# 21
# 17
# 23
# 51

# %% [markdown]
# For demonstration purpose we load a file with datetime information

# %%
file = 'FSIS-Recall-Summary-2014'
df = pd.read_csv('../data/{}.csv'.format(file), skiprows=1)
df.dropna()
df.head()
# Out:
#    Recall Date Recall Number Recall Class  \
# 0  Jan 10 2014      001-2014            I
# 1  Jan 13 2014      002-2014            I
# 2  Jan 15 2014      003-2014            I
# 3  Jan 17 2014      004-2014           II
# 4  Jan 17 2014      005-2014            I
#
#                                    Product       Reason for Recall  \
# 0  Mechanically Separated Chicken Products              Salmonella
# 1                    Various Beef Products                   Other
# 2                              Beef Franks     Undeclared Allergen
# 3                   Beef and Pork Products     Undeclared Allergen
# 4                              Spiral Hams  Listeria monocytogenes
#
#   Pounds Recalled
# 0          33,840
# 1          42,103
# 2           2,664
# 3         130,000
# 4          67,113

# %% [markdown]
# The `Recall Date` column looks like a Date Time format but it is not. We can simply transform it to a datetime format with `.to_datetime` method

# %%
print(df.dtypes)
# Out:
# Recall Date          object
# Recall Number        object
# Recall Class         object
# Product              object
# Reason for Recall    object
# Pounds Recalled      object
# dtype: object

# %%
df['Recall Date'] = pd.to_datetime(df['Recall Date'])

# %%
print(df.dtypes)
# Out:
# Recall Date          datetime64[ns]
# Recall Number                object
# Recall Class                 object
# Product                      object
# Reason for Recall            object
# Pounds Recalled              object
# dtype: object

# %% [markdown]
# Since we would like to calculate with Pounds Recalled down the road we transfer this to a float

# %%
#clean Pounds Recalled
df['Pounds Recalled'] = df['Pounds Recalled'].astype(str).str.replace(r",", "", regex=True).astype(float)

# %%
df.tail()
# Out:
#    Recall Date Recall Number Recall Class                    Product  \
# 90  2014-12-27      091-2014            I  Chicken and Beef Products
# 91  2014-12-29      092-2014            I     Beef and Pork Products
# 92  2014-12-31      093-2014            I           Chicken Products
# 93  2014-12-31      094-2014            I       Canned Soup Products
# 94         NaT           NaN          NaN                        NaN
#
#       Reason for Recall  Pounds Recalled
# 90  Undeclared Allergen          55813.0
# 91  Undeclared Allergen          38400.0
# 92  Undeclared Allergen           5300.0
# 93  Undeclared Allergen           4474.0
# 94                  NaN              NaN

# %% [markdown]
# Let us remove the last record since it contains NaN information

# %%
df = df[:-1]

# %% [markdown]
# We can add the day of year by using the attribure `dayofyear`

# %%
df['dayofyear'] = df['Recall Date'].dt.dayofyear
df.head()
# Out:
#   Recall Date Recall Number Recall Class  \
# 0  2014-01-10      001-2014            I
# 1  2014-01-13      002-2014            I
# 2  2014-01-15      003-2014            I
# 3  2014-01-17      004-2014           II
# 4  2014-01-17      005-2014            I
#
#                                    Product       Reason for Recall  \
# 0  Mechanically Separated Chicken Products              Salmonella
# 1                    Various Beef Products                   Other
# 2                              Beef Franks     Undeclared Allergen
# 3                   Beef and Pork Products     Undeclared Allergen
# 4                              Spiral Hams  Listeria monocytogenes
#
#    Pounds Recalled  dayofyear
# 0          33840.0         10
# 1          42103.0         13
# 2           2664.0         15
# 3         130000.0         17
# 4          67113.0         17

# %% [markdown]
# If we change the index to the datetime column we can use the `index.month`, `index.day`, `index.year` attributes derived from the datetime object. In the example below we first set the index to ddRecal and than select the month February

# %%
#Set data as index
df = df.rename(columns = {'Recall Date': 'ddRecal'})
df.index = df['ddRecal']
df = df.drop(['ddRecal'], axis = 1)
df.head()
# Out:
#            Recall Number Recall Class  \
# ddRecal
# 2014-01-10      001-2014            I
# 2014-01-13      002-2014            I
# 2014-01-15      003-2014            I
# 2014-01-17      004-2014           II
# 2014-01-17      005-2014            I
#
#                                             Product       Reason for Recall  \
# ddRecal
# 2014-01-10  Mechanically Separated Chicken Products              Salmonella
# 2014-01-13                    Various Beef Products                   Other
# 2014-01-15                              Beef Franks     Undeclared Allergen
# 2014-01-17                   Beef and Pork Products     Undeclared Allergen
# 2014-01-17                              Spiral Hams  Listeria monocytogenes
#
#             Pounds Recalled  dayofyear
# ddRecal
# 2014-01-10          33840.0         10
# 2014-01-13          42103.0         13
# 2014-01-15           2664.0         15
# 2014-01-17         130000.0         17
# 2014-01-17          67113.0         17

# %%
#select month 2
df_feb = df[(df.index.month == 2)] 
df_feb
# Out:
#            Recall Number Recall Class                            Product  \
# ddRecal
# 2014-02-01      009-2014           II  Various Meat and Poultry Products
# 2014-02-04      010-2014            I                      Beef Products
# 2014-02-04      011-2014            I                Chicken Noodle Soup
# 2014-02-08      012-2014            I                         Beef Jerky
# 2014-02-08      013-2014            I              Various Beef Products
# 2014-02-11      014-2014           II                Beef Jerky Products
# 2014-02-15      015-2014            I                 Dried Egg Products
# 2014-02-22      016-2014           II              Various Meat Products
# 2014-02-26      017-2014            I                         Liver Pâté
#
#                                    Reason for Recall  Pounds Recalled  \
# ddRecal
# 2014-02-01                       Undeclared Allergen         144000.0
# 2014-02-04  E. coli O103, O111, O121, O145, O26, O45          15865.0
# 2014-02-04                       Undeclared Allergen          54673.0
# 2014-02-08                         Processing Defect            365.0
# 2014-02-08                                     Other        8742700.0
# 2014-02-11                       Undeclared Allergen          90000.0
# 2014-02-15                                Salmonella         309594.0
# 2014-02-22                                     Other           8895.0
# 2014-02-26                                     Other           1282.0
#
#             dayofyear
# ddRecal
# 2014-02-01         32
# 2014-02-04         35
# 2014-02-04         35
# 2014-02-08         39
# 2014-02-08         39
# 2014-02-11         42
# 2014-02-15         46
# 2014-02-22         53
# 2014-02-26         57

# %%
#select first of all months
df_01 = df[(df.index.day == 1)] 
df_01
# Out:
#            Recall Number Recall Class                            Product  \
# ddRecal
# 2014-02-01      009-2014           II  Various Meat and Poultry Products
# 2014-04-01      019-2014            I                   Chicken Products
#
#               Reason for Recall  Pounds Recalled  dayofyear
# ddRecal
# 2014-02-01  Undeclared Allergen         144000.0         32
# 2014-04-01  Undeclared Allergen           8730.0         91

# %% [markdown]
# The month attribute is also handy when we want to find the month minimum value of a column.

# %%
#create a new column with month minimum of Pounds Recalled
df["min.recall"] = df.groupby([df.index.month])["Pounds Recalled"].transform('min')
df.head(10)
# Out:
#            Recall Number Recall Class  \
# ddRecal
# 2014-01-10      001-2014            I
# 2014-01-13      002-2014            I
# 2014-01-15      003-2014            I
# 2014-01-17      004-2014           II
# 2014-01-17      005-2014            I
# 2014-01-19      006-2014           II
# 2014-01-27      007-2014           II
# 2014-01-30      008-2014            I
# 2014-02-01      009-2014           II
# 2014-02-04      010-2014            I
#
#                                             Product  \
# ddRecal
# 2014-01-10  Mechanically Separated Chicken Products
# 2014-01-13                    Various Beef Products
# 2014-01-15                              Beef Franks
# 2014-01-17                   Beef and Pork Products
# 2014-01-17                              Spiral Hams
# 2014-01-19                Cheeseburger Mac Products
# 2014-01-27                  Frozen Chicken Products
# 2014-01-30                   Chicken Salad Products
# 2014-02-01        Various Meat and Poultry Products
# 2014-02-04                            Beef Products
#
#                                    Reason for Recall  Pounds Recalled  \
# ddRecal
# 2014-01-10                                Salmonella          33840.0
# 2014-01-13                                     Other          42103.0
# 2014-01-15                       Undeclared Allergen           2664.0
# 2014-01-17                       Undeclared Allergen         130000.0
# 2014-01-17                    Listeria monocytogenes          67113.0
# 2014-01-19                       Undeclared Allergen        1770000.0
# 2014-01-27                       Undeclared Allergen        1250000.0
# 2014-01-30                       Undeclared Allergen           2446.0
# 2014-02-01                       Undeclared Allergen         144000.0
# 2014-02-04  E. coli O103, O111, O121, O145, O26, O45          15865.0
#
#             dayofyear  min.recall
# ddRecal
# 2014-01-10         10      2446.0
# 2014-01-13         13      2446.0
# 2014-01-15         15      2446.0
# 2014-01-17         17      2446.0
# 2014-01-17         17      2446.0
# 2014-01-19         19      2446.0
# 2014-01-27         27      2446.0
# 2014-01-30         30      2446.0
# 2014-02-01         32       365.0
# 2014-02-04         35       365.0
